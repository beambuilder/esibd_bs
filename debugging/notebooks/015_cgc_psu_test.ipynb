# %% [markdown]
# # CGC PSU Test
#
# Notebook for testing the CGC PSU device class.

# %%
# Import required modules
import sys
import os
import logging
from datetime import datetime
from pathlib import Path

# Add src to path
sys.path.append(os.path.join(os.getcwd(), '..', '..', 'src'))

from devices.cgc.psu.psu import PSU
from devices.cgc.sw.sw import SW

# %% [markdown]
# ## Setup Logger & Create PSU Instance

# %%
# Setup external logger
repo_root = Path(os.getcwd()).parent.parent
log_dir = repo_root / "debugging" / "logs"
log_dir.mkdir(parents=True, exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
log_file = log_dir / f"015_SW_PSU_Debugging_{timestamp}.log"

logger = logging.getLogger(f"TPG366_PressureTest_{timestamp}")
logger.setLevel(logging.DEBUG)

file_handler = logging.FileHandler(log_file)
file_handler.setFormatter(logging.Formatter("%(asctime)s - %(levelname)s - %(message)s"))
logger.addHandler(file_handler)

console_handler = logging.StreamHandler()
console_handler.setFormatter(logging.Formatter("%(asctime)s - %(levelname)s - %(message)s"))
logger.addHandler(console_handler)

logger.info("Logger initialized.")
print(f"Log file: {log_file}")

# Create PSU instance on COM6 with external logger
psu = PSU("psu_test", com=6, port=0, logger=logger)
swA = SW("swA", com=8, port=0, logger=logger)   

print(f"Device ID: {psu.device_id}")
print(f"COM: {psu.com}")
print(f"Logger: {psu.logger.name}")
print(f"SW Device ID: {swA.device_id}")
print(f"SW COM: {swA.com}")
print(f"SW Logger: {swA.logger.name}")
# Out:
# 2026-02-17 14:19:35,599 - INFO - Logger initialized.
# Log file: C:\Users\ESIBDlab\PycharmProjects\esibd_bs\debugging\logs\015_SW_PSU_Debugging_20260217_141935.log
# Device ID: psu_test
# COM: 6
# Logger: TPG366_PressureTest_20260217_141935
# SW Device ID: swA
# SW COM: 8
# SW Logger: TPG366_PressureTest_20260217_141935

# %% [markdown]
# ## Function Calls PSU

# %%
psu.connect()# Add your function calls below
# Out:
# 2026-02-17 14:19:57,173 - INFO - Connecting to PSU device psu_test on COM6, port 0
# 2026-02-17 14:19:57,326 - INFO - Successfully connected to PSU device psu_test
# True

# %%
psu.get_main_state()
# Out:
# (0, '0x8004', 'STATE_ERR_ILOCK')

# %%
psu.get_interlock_enable()
# Out:
# (0, True, True)

# %%
psu.set_interlock_enable(True, True)
# Out:
# 0

# %%
psu.set_interlock_enable(False, False)
# Out:
# 0

# %%
psu.get_sensor_data()
# Out:
# (0, 11.81, 11.34, 11.28)

# %%
b = psu.get_config_list()

# %%
for i, elem in enumerate(b[1]):
    print(f"{i}: Name; {psu.get_config_name(i)} | Active;  {elem} | Valid; {b[2][i]}")
# Out:
# 0: Name; (0, '') | Active;  False | Valid; False
# 1: Name; (0, '') | Active;  False | Valid; False
# 2: Name; (0, '') | Active;  False | Valid; False
# 3: Name; (0, '') | Active;  False | Valid; False
# 4: Name; (0, '') | Active;  False | Valid; False
# 5: Name; (0, '') | Active;  False | Valid; False
# 6: Name; (0, '') | Active;  False | Valid; False
# 7: Name; (0, '') | Active;  False | Valid; False
# 8: Name; (0, '') | Active;  False | Valid; False
# 9: Name; (0, '') | Active;  False | Valid; False
# 10: Name; (0, '') | Active;  False | Valid; False
# 11: Name; (0, '') | Active;  False | Valid; False
# 12: Name; (0, '') | Active;  False | Valid; False
# 13: Name; (0, '') | Active;  False | Valid; False
# 14: Name; (0, '') | Active;  False | Valid; False
# 15: Name; (0, '') | Active;  False | Valid; False
# 16: Name; (0, '') | Active;  False | Valid; False
# 17: Name; (0, '') | Active;  False | Valid; False
# 18: Name; (0, '') | Active;  False | Valid; False
# 19: Name; (0, '') | Active;  False | Valid; False
# 20: Name; (0, '') | Active;  False | Valid; False
# 21: Name; (0, '') | Active;  False | Valid; False
# 22: Name; (0, '') | Active;  False | Valid; False
# 23: Name; (0, '') | Active;  False | Valid; False
# 24: Name; (0, '') | Active;  False | Valid; False
# 25: Name; (0, '') | Active;  False | Valid; False
# 26: Name; (0, '') | Active;  False | Valid; False
# 27: Name; (0, '') | Active;  False | Valid; False
# 28: Name; (0, '') | Active;  False | Valid; False
# 29: Name; (0, '') | Active;  False | Valid; False
# 30: Name; (0, '') | Active;  False | Valid; False
# 31: Name; (0, '') | Active;  False | Valid; False
# 32: Name; (0, '') | Active;  False | Valid; False
# 33: Name; (0, '') | Active;  False | Valid; False
# 34: Name; (0, '') | Active;  False | Valid; False
# 35: Name; (0, '') | Active;  False | Valid; False
# 36: Name; (0, '') | Active;  False | Valid; False
# 37: Name; (0, '') | Active;  False | Valid; False
# 38: Name; (0, '') | Active;  False | Valid; False
# 39: Name; (0, '') | Active;  False | Valid; False
# 40: Name; (0, '') | Active;  False | Valid; False
# 41: Name; (0, '') | Active;  False | Valid; False
# 42: Name; (0, 'config42') | Active;  True | Valid; True
# 43: Name; (0, '') | Active;  False | Valid; False
# 44: Name; (0, '') | Active;  False | Valid; False
# 45: Name; (0, '') | Active;  False | Valid; False
# 46: Name; (0, '') | Active;  False | Valid; False
# 47: Name; (0, '') | Active;  False | Valid; False
# 48: Name; (0, '') | Active;  False | Valid; False
# 49: Name; (0, '') | Active;  False | Valid; False
# 50: Name; (0, '') | Active;  False | Valid; False
# 51: Name; (0, '') | Active;  False | Valid; False
# 52: Name; (0, '') | Active;  False | Valid; False
# 53: Name; (0, '') | Active;  False | Valid; False
# 54: Name; (0, '') | Active;  False | Valid; False
# 55: Name; (0, '') | Active;  False | Valid; False
# 56: Name; (0, '') | Active;  False | Valid; False
# 57: Name; (0, '') | Active;  False | Valid; False
# 58: Name; (0, '') | Active;  False | Valid; False
# 59: Name; (0, '') | Active;  False | Valid; False
# 60: Name; (0, '') | Active;  False | Valid; False
# 61: Name; (0, '') | Active;  False | Valid; False
# 62: Name; (0, '') | Active;  False | Valid; False
# 63: Name; (0, '') | Active;  False | Valid; False
# 64: Name; (0, '') | Active;  False | Valid; False
# 65: Name; (0, '') | Active;  False | Valid; False
# 66: Name; (0, '') | Active;  False | Valid; False
# 67: Name; (0, '') | Active;  False | Valid; False
# 68: Name; (0, '') | Active;  False | Valid; False
# 69: Name; (0, '') | Active;  False | Valid; False
# 70: Name; (0, '') | Active;  False | Valid; False
# 71: Name; (0, '') | Active;  False | Valid; False
# 72: Name; (0, '') | Active;  False | Valid; False
# 73: Name; (0, '') | Active;  False | Valid; False
# 74: Name; (0, '') | Active;  False | Valid; False
# 75: Name; (0, '') | Active;  False | Valid; False
# 76: Name; (0, '') | Active;  False | Valid; False
# 77: Name; (0, '') | Active;  False | Valid; False
# 78: Name; (0, '') | Active;  False | Valid; False
# 79: Name; (0, '') | Active;  False | Valid; False
# 80: Name; (0, '') | Active;  False | Valid; False
# 81: Name; (0, '') | Active;  False | Valid; False
# 82: Name; (0, '') | Active;  False | Valid; False
# 83: Name; (0, '') | Active;  False | Valid; False
# 84: Name; (0, '') | Active;  False | Valid; False
# 85: Name; (0, '') | Active;  False | Valid; False
# 86: Name; (0, '') | Active;  False | Valid; False
# 87: Name; (0, '') | Active;  False | Valid; False
# 88: Name; (0, '') | Active;  False | Valid; False
# 89: Name; (0, '') | Active;  False | Valid; False
# 90: Name; (0, '') | Active;  False | Valid; False
# 91: Name; (0, '') | Active;  False | Valid; False
# 92: Name; (0, '') | Active;  False | Valid; False
# 93: Name; (0, '') | Active;  False | Valid; False
# 94: Name; (0, '') | Active;  False | Valid; False
# 95: Name; (0, '') | Active;  False | Valid; False
# 96: Name; (0, '') | Active;  False | Valid; False
# 97: Name; (0, '') | Active;  False | Valid; False
# 98: Name; (0, '') | Active;  False | Valid; False
# 99: Name; (0, '') | Active;  False | Valid; False
# 100: Name; (0, '') | Active;  False | Valid; False
# 101: Name; (0, '') | Active;  False | Valid; False
# 102: Name; (0, '') | Active;  False | Valid; False
# 103: Name; (0, '') | Active;  False | Valid; False
# 104: Name; (0, '') | Active;  False | Valid; False
# 105: Name; (0, '') | Active;  False | Valid; False
# 106: Name; (0, '') | Active;  False | Valid; False
# 107: Name; (0, '') | Active;  False | Valid; False
# 108: Name; (0, '') | Active;  False | Valid; False
# 109: Name; (0, '') | Active;  False | Valid; False
# 110: Name; (0, '') | Active;  False | Valid; False
# 111: Name; (0, '') | Active;  False | Valid; False
# 112: Name; (0, '') | Active;  False | Valid; False
# 113: Name; (0, '') | Active;  False | Valid; False
# 114: Name; (0, '') | Active;  False | Valid; False
# 115: Name; (0, '') | Active;  False | Valid; False
# 116: Name; (0, '') | Active;  False | Valid; False
# 117: Name; (0, '') | Active;  False | Valid; False
# 118: Name; (0, '') | Active;  False | Valid; False
# 119: Name; (0, '') | Active;  False | Valid; False
# 120: Name; (0, '') | Active;  False | Valid; False
# 121: Name; (0, '') | Active;  False | Valid; False
# 122: Name; (0, '') | Active;  False | Valid; False
# 123: Name; (0, '') | Active;  False | Valid; False
# 124: Name; (0, '') | Active;  False | Valid; False
# 125: Name; (0, '') | Active;  False | Valid; False
# 126: Name; (0, '') | Active;  False | Valid; False
# 127: Name; (0, '') | Active;  False | Valid; False
# 128: Name; (0, '') | Active;  False | Valid; False
# 129: Name; (0, '') | Active;  False | Valid; False
# 130: Name; (0, '') | Active;  False | Valid; False
# 131: Name; (0, '') | Active;  False | Valid; False
# 132: Name; (0, '') | Active;  False | Valid; False
# 133: Name; (0, '') | Active;  False | Valid; False
# 134: Name; (0, '') | Active;  False | Valid; False
# 135: Name; (0, '') | Active;  False | Valid; False
# 136: Name; (0, '') | Active;  False | Valid; False
# 137: Name; (0, '') | Active;  False | Valid; False
# 138: Name; (0, '') | Active;  False | Valid; False
# 139: Name; (0, '') | Active;  False | Valid; False
# 140: Name; (0, '') | Active;  False | Valid; False
# 141: Name; (0, '') | Active;  False | Valid; False
# 142: Name; (0, '') | Active;  False | Valid; False
# 143: Name; (0, '') | Active;  False | Valid; False
# 144: Name; (0, '') | Active;  False | Valid; False
# 145: Name; (0, '') | Active;  False | Valid; False
# 146: Name; (0, '') | Active;  False | Valid; False
# 147: Name; (0, '') | Active;  False | Valid; False
# 148: Name; (0, '') | Active;  False | Valid; False
# 149: Name; (0, '') | Active;  False | Valid; False
# 150: Name; (0, '') | Active;  False | Valid; False
# 151: Name; (0, '') | Active;  False | Valid; False
# 152: Name; (0, '') | Active;  False | Valid; False
# 153: Name; (0, '') | Active;  False | Valid; False
# 154: Name; (0, '') | Active;  False | Valid; False
# 155: Name; (0, '') | Active;  False | Valid; False
# 156: Name; (0, '') | Active;  False | Valid; False
# 157: Name; (0, '') | Active;  False | Valid; False
# 158: Name; (0, '') | Active;  False | Valid; False
# 159: Name; (0, '') | Active;  False | Valid; False
# 160: Name; (0, '') | Active;  False | Valid; False
# 161: Name; (0, '') | Active;  False | Valid; False
# 162: Name; (0, '') | Active;  False | Valid; False
# 163: Name; (0, '') | Active;  False | Valid; False
# 164: Name; (0, '') | Active;  False | Valid; False
# 165: Name; (0, '') | Active;  False | Valid; False
# 166: Name; (0, '') | Active;  False | Valid; False
# 167: Name; (0, '') | Active;  False | Valid; False

# %%
42: Name; (0, 'config42') | Active;  True | Valid; True

# %%
psu.disconnect()
# Out:
# 2026-02-17 15:42:53,543 - INFO - Housekeeping stopped (internal mode)
# 2026-02-17 15:42:53,544 - INFO - Disconnecting PSU device psu_test
# 2026-02-17 15:42:53,553 - INFO - Successfully disconnected PSU device psu_test
# True

# %% [markdown]
# ## Function Calls Switch

# %%
swA.connect()
# Out:
# 2026-02-17 14:20:19,129 - INFO - Connecting to SW device swA on COM8, port 0
# 2026-02-17 14:20:19,285 - INFO - Successfully connected to SW device swA (baud rate: 230400)
# True

# %%
a = swA.get_config_list()

# %%
for i, elem in enumerate(a[1]):
    print(f"{i}: Name; {swA.get_config_name(i)} | Active;  {elem} | Valid; {a[2][i]}")
# Out:
# 0: Name; (0, 'Standby') | Active;  True | Valid; True
# 1: Name; (0, 'DIO2->DIO1,3-7') | Active;  True | Valid; True
# 2: Name; (0, 'DIO3->DIO1-2,4-7') | Active;  True | Valid; True
# 3: Name; (0, 'DIO4->DIO1-3,5-7') | Active;  True | Valid; True
# 4: Name; (0, 'DIO5->DIO1-4,6-7') | Active;  True | Valid; True
# 5: Name; (0, 'DIO6->DIO1-5,7') | Active;  True | Valid; True
# 6: Name; (0, 'DIO7->DIO1-6') | Active;  True | Valid; True
# 7: Name; (0, '') | Active;  False | Valid; False
# 8: Name; (0, '') | Active;  False | Valid; False
# 9: Name; (0, 'Static:Out0-3=Hi-Z') | Active;  True | Valid; True
# 10: Name; (0, 'Static:Out0-3=Vneg') | Active;  True | Valid; True
# 11: Name; (0, 'Static:Out0-3=Vpos') | Active;  True | Valid; True
# 12: Name; (0, 'DIO3(Term)->DIO1-2,4-7') | Active;  True | Valid; True
# 13: Name; (0, 'DIO4(Term)->DIO1-3,5-7') | Active;  True | Valid; True
# 14: Name; (0, 'DIO5(Term)->DIO1-4,6-7') | Active;  True | Valid; True
# 15: Name; (0, 'DIO6(Term)->DIO1-5,7') | Active;  True | Valid; True
# 16: Name; (0, 'DIO7(Term)->DIO1-6') | Active;  True | Valid; True
# 17: Name; (0, '') | Active;  False | Valid; False
# 18: Name; (0, '') | Active;  False | Valid; False
# 19: Name; (0, 'Static:DIO0-DIO6=log0') | Active;  True | Valid; True
# 20: Name; (0, 'Static:DIO0-DIO6=log1') | Active;  True | Valid; True
# 21: Name; (0, '1kHz->DIO0-DIO6') | Active;  True | Valid; True
# 22: Name; (0, '') | Active;  False | Valid; False
# 23: Name; (0, '') | Active;  False | Valid; False
# 24: Name; (0, '') | Active;  False | Valid; False
# 25: Name; (0, '') | Active;  False | Valid; False
# 26: Name; (0, '') | Active;  False | Valid; False
# 27: Name; (0, '') | Active;  False | Valid; False
# 28: Name; (0, '') | Active;  False | Valid; False
# 29: Name; (0, 'DIO0->2xSwitchSym,DIO0->DIO1,1kHz->DIO2') | Active;  True | Valid; True
# 30: Name; (0, 'DIO0->Switch0-3,DIO0->DIO1,1kHz->DIO2') | Active;  True | Valid; True
# 31: Name; (0, '') | Active;  False | Valid; False
# 32: Name; (0, '') | Active;  False | Valid; False
# 33: Name; (0, '') | Active;  False | Valid; False
# 34: Name; (0, '') | Active;  False | Valid; False
# 35: Name; (0, '') | Active;  False | Valid; False
# 36: Name; (0, '') | Active;  False | Valid; False
# 37: Name; (0, '') | Active;  False | Valid; False
# 38: Name; (0, '') | Active;  False | Valid; False
# 39: Name; (0, '1kHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 40: Name; (0, '') | Active;  False | Valid; False
# 41: Name; (0, '') | Active;  False | Valid; False
# 42: Name; (0, '') | Active;  False | Valid; False
# 43: Name; (0, '') | Active;  False | Valid; False
# 44: Name; (0, '1kHz->SwitchSym(0/90deg)+DIO0/1,Osc->DIO2') | Active;  True | Valid; True
# 45: Name; (0, '') | Active;  False | Valid; False
# 46: Name; (0, '') | Active;  False | Valid; False
# 47: Name; (0, '') | Active;  False | Valid; False
# 48: Name; (0, '') | Active;  False | Valid; False
# 49: Name; (0, '10kHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 50: Name; (0, '') | Active;  False | Valid; False
# 51: Name; (0, '') | Active;  False | Valid; False
# 52: Name; (0, '') | Active;  False | Valid; False
# 53: Name; (0, '') | Active;  False | Valid; False
# 54: Name; (0, '') | Active;  False | Valid; False
# 55: Name; (0, '') | Active;  False | Valid; False
# 56: Name; (0, '') | Active;  False | Valid; False
# 57: Name; (0, '') | Active;  False | Valid; False
# 58: Name; (0, '') | Active;  False | Valid; False
# 59: Name; (0, '100kHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 60: Name; (0, '') | Active;  False | Valid; False
# 61: Name; (0, '') | Active;  False | Valid; False
# 62: Name; (0, '') | Active;  False | Valid; False
# 63: Name; (0, '') | Active;  False | Valid; False
# 64: Name; (0, '') | Active;  False | Valid; False
# 65: Name; (0, '') | Active;  False | Valid; False
# 66: Name; (0, '') | Active;  False | Valid; False
# 67: Name; (0, '') | Active;  False | Valid; False
# 68: Name; (0, '') | Active;  False | Valid; False
# 69: Name; (0, '250kHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 70: Name; (0, '') | Active;  False | Valid; False
# 71: Name; (0, '') | Active;  False | Valid; False
# 72: Name; (0, '') | Active;  False | Valid; False
# 73: Name; (0, '') | Active;  False | Valid; False
# 74: Name; (0, '400kHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 75: Name; (0, '') | Active;  False | Valid; False
# 76: Name; (0, '') | Active;  False | Valid; False
# 77: Name; (0, '') | Active;  False | Valid; False
# 78: Name; (0, '') | Active;  False | Valid; False
# 79: Name; (0, '500kHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 80: Name; (0, '') | Active;  False | Valid; False
# 81: Name; (0, '') | Active;  False | Valid; False
# 82: Name; (0, '') | Active;  False | Valid; False
# 83: Name; (0, '') | Active;  False | Valid; False
# 84: Name; (0, '') | Active;  False | Valid; False
# 85: Name; (0, '') | Active;  False | Valid; False
# 86: Name; (0, '') | Active;  False | Valid; False
# 87: Name; (0, '') | Active;  False | Valid; False
# 88: Name; (0, '') | Active;  False | Valid; False
# 89: Name; (0, '1MHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 90: Name; (0, '') | Active;  False | Valid; False
# 91: Name; (0, '') | Active;  False | Valid; False
# 92: Name; (0, '') | Active;  False | Valid; False
# 93: Name; (0, '') | Active;  False | Valid; False
# 94: Name; (0, '') | Active;  False | Valid; False
# 95: Name; (0, '') | Active;  False | Valid; False
# 96: Name; (0, '') | Active;  False | Valid; False
# 97: Name; (0, '') | Active;  False | Valid; False
# 98: Name; (0, '') | Active;  False | Valid; False
# 99: Name; (0, '0.84MHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 100: Name; (0, '') | Active;  False | Valid; False
# 101: Name; (0, '1.2MHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 102: Name; (0, '1.5MHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 103: Name; (0, '2MHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 104: Name; (0, '3MHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 105: Name; (0, '4MHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 106: Name; (0, '5MHz->SwitchSym+DIO0,Osc->DIO1') | Active;  True | Valid; True
# 107: Name; (0, '') | Active;  False | Valid; False
# 108: Name; (0, '') | Active;  False | Valid; False
# 109: Name; (0, '5000x1MHz->SwitchSym+DIO0,Pause->Vneg+DIO1') | Active;  True | Valid; True
# 110: Name; (0, '') | Active;  False | Valid; False
# 111: Name; (0, '') | Active;  False | Valid; False
# 112: Name; (0, '') | Active;  False | Valid; False
# 113: Name; (0, '') | Active;  False | Valid; False
# 114: Name; (0, '') | Active;  False | Valid; False
# 115: Name; (0, '') | Active;  False | Valid; False
# 116: Name; (0, '') | Active;  False | Valid; False
# 117: Name; (0, '') | Active;  False | Valid; False
# 118: Name; (0, '') | Active;  False | Valid; False
# 119: Name; (0, '') | Active;  False | Valid; False
# 120: Name; (0, '') | Active;  False | Valid; False
# 121: Name; (0, '') | Active;  False | Valid; False
# 122: Name; (0, '') | Active;  False | Valid; False
# 123: Name; (0, '') | Active;  False | Valid; False
# 124: Name; (0, '') | Active;  False | Valid; False
# 125: Name; (0, '') | Active;  False | Valid; False

# %%
swA.get_controller_state()
# Out:
# (0, '0x0', [])

# %%
swA.get_device_enable()
# Out:
# (0, True)

# %%
swA.load_current_config(0)
# Out:
# 0

# %%
swA.get_sensor_data()
# Out:
# (0, 0.21, 11.34, 11.22)

# %%
swA.disconnect()
# Out:
# 2026-02-17 15:42:48,801 - INFO - Housekeeping thread stopped
# 2026-02-17 15:42:48,802 - INFO - Disconnecting SW device swA
# 2026-02-17 15:42:48,811 - INFO - Successfully disconnected SW device swA
# True

# %%
psu.start_housekeeping(interval= 1)
swA.start_housekeeping(interval= 1)
# Out:
# 2026-02-17 14:20:42,742 - INFO - Housekeeping worker started for psu_test
# 2026-02-17 14:20:42,742 - INFO - Housekeeping started (internal mode) - interval: 1s
# 2026-02-17 14:20:42,745 - INFO - Housekeeping worker started for swA
# 2026-02-17 14:20:42,745 - INFO - Housekeeping thread started with 1s interval
# 2026-02-17 14:20:42,746 - INFO - Product number: 121604
# 2026-02-17 14:20:42,748 - DEBUG - Product number: 124902
# True
# 2026-02-17 14:20:42,749 - INFO - Main state: STATE_ERR_ILOCK
# 2026-02-17 14:20:42,750 - DEBUG - Main state: STATE_ERR_FPGA_DIS (0x8004)

# %% [markdown]
# # Set Configs, first test

# %%
psu.get_interlock_enable()
# Out:
# (0, False, False)

# %%
psu.get_main_state()
# Out:
# (0, '0x0', 'STATE_ON')

# %%
psu.get_device_enable()
# Out:
# (0, True)

# %%
psu.reset_current_config()
# Out:
# 0

# %%
psu.get_psu0_data()
# Out:
# (0, 0.116, 0.0, 498.084)

# %%
psu.get_psu1_data()
# Out:
# (0, 0.117, 0.0, 499.568)

# %%
psu.get_psu0_set_output_voltage()
# Out:
# (0, 0.0, 350.002)

# %%
psu.get_psu0_output_voltage()
# Out:
# 2026-02-17 15:07:03,940 - INFO - PSU0 output voltage: 0.000V
# (0, 0.0)

# %%
psu.set_psu0_output_voltage(0)
psu.set_psu1_output_voltage(0)
# Out:
# 2026-02-17 15:15:47,256 - INFO - Setting PSU0 output voltage to 0.000V
# 2026-02-17 15:15:47,258 - INFO - PSU0 output voltage set successfully
# 2026-02-17 15:15:47,258 - INFO - Setting PSU1 output voltage to 0.000V
# 2026-02-17 15:15:47,260 - INFO - PSU1 output voltage set successfully
# 0

# %%
psu.set_psu0_output_current(0)
# Out:
# 0

# %%
psu.set_psu0_output_current(0.1)
# Out:
# 0

# %%
psu.get_psu_output_current(0)
# Out:
# (0, 0.0)

# %%
psu.get_psu_set_output_current(0)
# Out:
# (0, 0.0, 0.524974)

# %% [markdown]
# ## Switch set to Config

# %%
swA.load_current_config(0)
# Out:
# 0

# %%
swA.get_sensor_data()
# Out:
# (0, 0.2, 11.43, 11.3)

# %%
swA.set_pulser_width(0, 24998)
# Out:
# 2026-02-17 15:41:58,040 - INFO - Setting pulser 0 width to 24998
# 2026-02-17 15:41:58,043 - INFO - Pulser 0 width set successfully
# 0

# %%
swA.set_pulser_width(0, 49998)
# Out:
# 2026-02-17 15:42:07,509 - INFO - Setting pulser 0 width to 49998
# 2026-02-17 15:42:07,511 - INFO - Pulser 0 width set successfully
# 0
