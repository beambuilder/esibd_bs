# %% [markdown]
# # PA (DMMR-8) Testing

# %% [markdown]
# ## Imports + Logger

# %%
import sys
import os
import logging
from datetime import datetime
from pathlib import Path

sys.path.append(os.path.join(os.getcwd(), '..', '..', 'src'))

from devices.cgc.pA import PA

# %%
repo_root = Path(os.getcwd()).parent.parent
log_dir = repo_root / "debugging" / "logs"
log_dir.mkdir(parents=True, exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
log_file = log_dir / f"017_Testing_pA_{timestamp}.log"

logger = logging.getLogger(f"017_Testing_pA_{timestamp}")
logger.setLevel(logging.DEBUG)

file_handler = logging.FileHandler(log_file)
file_handler.setFormatter(logging.Formatter("%(asctime)s - %(levelname)s - %(message)s"))
logger.addHandler(file_handler)

console_handler = logging.StreamHandler()
console_handler.setFormatter(logging.Formatter("%(asctime)s - %(levelname)s - %(message)s"))
logger.addHandler(console_handler)

logger.info("Logger initialized.")
print(f"Log file: {log_file}")
# Out:
# 2026-03-25 10:43:12,740 - INFO - Logger initialized.
# Log file: C:\Users\ESIBDlab\PycharmProjects\esibd_bs\debugging\logs\017_Testing_pA_20260325_104312.log

# %% [markdown]
# ## Create Instance + Connect

# %%
COM_PORT = 9  # adjust as needed
MOD_ADDR = 0  # module address for module-level tests

pa = PA("test_pa", com=COM_PORT, logger=logger)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 4
#       1 COM_PORT = 9  # adjust as needed
#       2 MOD_ADDR = 0  # module address for module-level tests
# ----> 4 pa = PA("test_pa", com=COM_PORT, logger=logger)
#
# File ~\PycharmProjects\esibd_bs\debugging\notebooks\..\..\src\devices\cgc\pA\pA.py:119, in PA.__init__(self, device_id, com, baudrate, logger, hk_thread, thread_lock, hk_interval, **kwargs)
#     116         self.logger.info(f"Baudrate: {baudrate}")
#     118 # Initialize the base class
# --> 119 super().__init__(com=com, log=None, idn=device_id)
#
# File ~\PycharmProjects\esibd_bs\debugging\notebooks\..\..\src\devices\cgc\pA\pA_base.py:145, in PABase.__init__(self, com, log, idn)
#     143 # Importing dll for hardware control - path relative to pA_base.py
#     144 self.dll_path = os.path.join(self.class_dir, r"DMMR-8_1-01\x86\COM-DMMR-8.dll")
# --> 145 self.dll = ctypes.WinDLL(self.dll_path)
#     147 # Importing error messages - path relative to cgc folder
#     148 self.err_path = os.path.join(os.path.dirname(self.class_dir), "error_codes.json")
#
# File ~\anaconda3\envs\esibd\Lib\ctypes\__init__.py:379, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     376 self._FuncPtr = _FuncPtr
#     378 if handle is None:
# --> 379     self._handle = _dlopen(self._name, mode)
#     380 else:
#     381     self._handle = handle
#
# OSError: [WinError 193] %1 ist keine zulässige Win32-Anwendung

# %%
pa.connect()

# %% [markdown]
# ## Software / Firmware Info

# %%
pa.get_sw_version()

# %%
pa.get_fw_version()

# %%
pa.get_fw_date()

# %%
pa.get_product_id()

# %%
pa.get_product_no()

# %%
pa.get_manuf_date()

# %%
pa.get_device_type()

# %%
pa.get_hw_type()

# %%
pa.get_hw_version()

# %% [markdown]
# ## Uptime / Optime

# %%
pa.get_uptime()

# %%
pa.get_uptime_int()

# %%
pa.get_optime()

# %%
pa.get_optime_int()

# %% [markdown]
# ## CPU + Housekeeping

# %%
pa.get_cpu_data()

# %%
pa.get_housekeeping()

# %% [markdown]
# ## Controller States

# %%
pa.get_state()

# %%
pa.get_device_state()

# %%
pa.get_voltage_state()

# %%
pa.get_temperature_state()

# %%
pa.get_enable()

# %%
pa.set_enable(True)

# %%
pa.get_enable()

# %% [markdown]
# ## Base Device

# %%
pa.get_base_product_no()

# %%
pa.get_base_manuf_date()

# %%
pa.get_base_hw_version()

# %%
pa.get_base_hw_type()

# %%
pa.get_base_state()

# %%
pa.get_base_temp()

# %%
pa.get_base_led_data()

# %%
pa.get_base_fan_pwm()

# %%
pa.get_base_fan_rpm()

# %% [markdown]
# ## Communication Buffers

# %%
pa.get_buffer_state()

# %%
pa.purge()

# %%
pa.device_purge()

# %%
pa.get_auto_mask()

# %%
pa.check_auto_input()

# %% [markdown]
# ## Module Discovery

# %%
pa.get_module_presence()

# %%
pa.update_module_presence()

# %%
pa.rescan_modules()

# %%
pa.get_scanned_module_state()

# %%
pa.scan_modules()

# %% [markdown]
# ## Module Info (MOD_ADDR)

# %%
pa.get_module_info(MOD_ADDR)

# %%
pa.get_module_fw_version(MOD_ADDR)

# %%
pa.get_module_fw_date(MOD_ADDR)

# %%
pa.get_module_product_id(MOD_ADDR)

# %%
pa.get_module_product_no(MOD_ADDR)

# %%
pa.get_module_manuf_date(MOD_ADDR)

# %%
pa.get_module_device_type(MOD_ADDR)

# %%
pa.get_module_hw_type(MOD_ADDR)

# %%
pa.get_module_hw_version(MOD_ADDR)

# %%
pa.get_module_uptime(MOD_ADDR)

# %%
pa.get_module_uptime_int(MOD_ADDR)

# %%
pa.get_module_optime(MOD_ADDR)

# %%
pa.get_module_optime_int(MOD_ADDR)

# %%
pa.get_module_cpu_data(MOD_ADDR)

# %%
pa.get_module_housekeeping(MOD_ADDR)

# %%
pa.get_module_state(MOD_ADDR)

# %%
pa.get_module_buffer_state(MOD_ADDR)

# %%
pa.get_module_ready_flags(MOD_ADDR)

# %%
pa.get_scanned_module_params(MOD_ADDR)

# %% [markdown]
# ## Module Measurement

# %%
pa.get_module_meas_range(MOD_ADDR)

# %%
pa.set_module_auto_range(MOD_ADDR, True)

# %%
pa.set_module_meas_range(MOD_ADDR, 0)

# %%
pa.get_module_current(MOD_ADDR)

# %% [markdown]
# ## Automatic Current

# %%
pa.get_automatic_current()

# %%
pa.set_automatic_current(True)

# %%
pa.get_automatic_current()

# %%
pa.get_current()

# %%
pa.set_automatic_current(False)

# %% [markdown]
# ## Configuration

# %%
pa.get_current_config()

# %%
pa.get_config_flags(0)

# %%
pa.get_config_name(0)

# %%
pa.get_config_data(0)

# %% [markdown]
# ## Error / Interface State

# %%
pa.get_interface_state()

# %%
pa.get_error_message()

# %%
pa.get_io_state()

# %%
pa.get_io_error_message()

# %%
pa.get_comm_error()

# %% [markdown]
# ## PA Convenience Methods

# %%
pa.get_status()

# %%
pa.hk_monitor()

# %% [markdown]
# ## Housekeeping Thread

# %%
pa.start_housekeeping(interval=5)

# %%
import time
time.sleep(10)  # let housekeeping run ~2 cycles

# %%
pa.stop_housekeeping()

# %% [markdown]
# ## Disable + Disconnect

# %%
pa.set_enable(False)

# %%
pa.disconnect()

# %%
print(f"Log file: {log_file}")
