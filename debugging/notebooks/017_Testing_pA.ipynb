# %% [markdown]
# # PA (DMMR-8) Testing

# %% [markdown]
# ## Imports + Logger

# %%
import sys
import os
import logging
from datetime import datetime
from pathlib import Path

sys.path.append(os.path.join(os.getcwd(), '..', '..', 'src'))

from devices.cgc.pA import PA

# %%
repo_root = Path(os.getcwd()).parent.parent
log_dir = repo_root / "debugging" / "logs"
log_dir.mkdir(parents=True, exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
log_file = log_dir / f"017_Testing_pA_{timestamp}.log"

logger = logging.getLogger(f"017_Testing_pA_{timestamp}")
logger.setLevel(logging.DEBUG)

file_handler = logging.FileHandler(log_file)
file_handler.setFormatter(logging.Formatter("%(asctime)s - %(levelname)s - %(message)s"))
logger.addHandler(file_handler)

console_handler = logging.StreamHandler()
console_handler.setFormatter(logging.Formatter("%(asctime)s - %(levelname)s - %(message)s"))
logger.addHandler(console_handler)

logger.info("Logger initialized.")
print(f"Log file: {log_file}")
# Out:
# 2026-03-25 12:18:01,195 - INFO - Logger initialized.
# Log file: C:\Users\ESIBDlab\PycharmProjects\esibd_bs\debugging\logs\017_Testing_pA_20260325_121801.log

# %% [markdown]
# ## Create Instance + Connect

# %%
COM_PORT = 9  # adjust as needed
MOD_ADDR = 0  # module address for module-level tests

pa = PA("test_pa", com=COM_PORT, logger=logger)

# %%
pa.connect()
# Out:
# 2026-03-25 12:20:25,292 - INFO - test_pa - Connecting to PA device test_pa on COM9
# 2026-03-25 12:20:25,418 - INFO - test_pa - Successfully connected to PA device test_pa
# 2026-03-25 12:20:25,438 - INFO - test_pa - Baud rate set to 230400
# True

# %% [markdown]
# ## Software / Firmware Info

# %%
pa.get_sw_version()
# Out:
# 258

# %%
pa.get_fw_version()
# Out:
# (0, 257)

# %%
pa.get_fw_date()
# Out:
# (0, 'Feb 13 2025')

# %%
pa.get_product_id()
# Out:
# (0, 'Controller for DMMR Devices')

# %%
pa.get_product_no()
# Out:
# (0, 124630)

# %%
pa.get_manuf_date()
# Out:
# (0, 2024, 40)

# %%
pa.get_device_type()
# Out:
# (0, 44088)

# %%
pa.get_hw_type()
# Out:
# (0, 2236480)

# %%
pa.get_hw_version()
# Out:
# (0, 256)

# %% [markdown]
# ## Uptime / Optime

# %%
pa.get_uptime()
# Out:
# (0, 6233.64453125, 202256.037109375)

# %%
pa.get_uptime_int()
# Out:
# (0, 6234, 838, 202257, 232)

# %%
pa.get_optime()
# Out:
# (0, 0.0, 0.0)

# %%
pa.get_optime_int()
# Out:
# (0, 0, 0, 0, 0)

# %% [markdown]
# ## CPU + Housekeeping

# %%
pa.get_cpu_data()
# Out:
# (0, 0.878, 15691776.0)

# %%
pa.get_housekeeping()
# Out:
# (0, 11.969, 5.004, 3.303, 23.65)

# %% [markdown]
# ## Controller States

# %%
pa.get_state()
# Out:
# 2026-03-25 12:21:56,534 - INFO - test_pa - Main state: ST_ON (0x0)
# (0, '0x0', 'ST_ON')

# %%
pa.get_device_state()
# Out:
# (0, '0x0', ['DEVICE_OK'])

# %%
pa.get_voltage_state()
# Out:
# (0, '0x7', ['VS_3V3_OK', 'VS_5V0_OK', 'VS_12V_OK'])

# %%
pa.get_temperature_state()
# Out:
# (0, '0x0', ['TEMPERATURE_OK'])

# %%
pa.get_enable()
# Out:
# (0, False)

# %%
pa.set_enable(True)
# Out:
# 2026-03-25 12:22:19,641 - INFO - test_pa - Setting module enable to True
# 2026-03-25 12:22:19,642 - INFO - test_pa - Module enable set to True
# 0

# %%
pa.get_enable()
# Out:
# (0, True)

# %% [markdown]
# ## Base Device

# %%
pa.get_base_product_no()
# Out:
# (0, 124623)

# %%
pa.get_base_manuf_date()
# Out:
# (0, 2024, 40)

# %%
pa.get_base_hw_version()
# Out:
# (0, 266)

# %%
pa.get_base_hw_type()
# Out:
# (0, 5080)

# %%
pa.get_base_state()
# Out:
# (0,
#  '0x4e80',
#  ['BS_ENB', 'BS_ENABLE', 'BS_ILOCK_IN', 'BS_ILOCK_OUT', 'BS_ON_TEMP'])

# %%
pa.get_base_temp()
# Out:
# (0, 27.13)

# %%
pa.get_base_led_data()
# Out:
# (0, False, False, False)

# %%
pa.get_base_fan_pwm()
# Out:
# (0, 0, '0x1600', ['FAN_OK', 'FAN_PWM_DIS', 'FAN_INSTAL'])

# %%
pa.get_base_fan_rpm()
# Out:
# (0, 0.0)

# %% [markdown]
# ## Communication Buffers

# %%
pa.get_buffer_state()
# Out:
# (-13, False)

# %%
pa.purge()
# Out:
# 0

# %%
pa.device_purge()
# Out:
# (-13, False)

# %%
pa.get_auto_mask()
# Out:
# (0, 0)

# %%
pa.check_auto_input()
# Out:
# (0, 0)

# %% [markdown]
# ## Module Discovery

# %%
pa.get_module_presence()
# Out:
# (0, True, 8, [1, 1, 1, 1, 1, 0, 0, 0])

# %%
pa.update_module_presence()
# Out:
# 0

# %%
pa.rescan_modules()
# Out:
# 0

# %%
pa.get_scanned_module_state()
# Out:
# (0, False)

# %%
pa.scan_modules()
# Out:
# 2026-03-25 12:26:29,664 - INFO - test_pa - Scanning for connected modules
# 2026-03-25 12:26:30,086 - INFO - test_pa - Found 5 modules:
# 2026-03-25 12:26:30,087 - INFO - test_pa -   Module 0: Product 124625, FW 257, State 0
# 2026-03-25 12:26:30,087 - INFO - test_pa -   Module 1: Product 124626, FW 257, State 0
# 2026-03-25 12:26:30,087 - INFO - test_pa -   Module 2: Product 124627, FW 257, State 0
# 2026-03-25 12:26:30,088 - INFO - test_pa -   Module 3: Product 124628, FW 257, State 0
# 2026-03-25 12:26:30,088 - INFO - test_pa -   Module 4: Product 124629, FW 257, State 0
# {0: {'fw_version': 257,
#   'product_no': 124625,
#   'hw_type': 4734992,
#   'hw_version': 276,
#   'state': 0},
#  1: {'fw_version': 257,
#   'product_no': 124626,
#   'hw_type': 4734992,
#   'hw_version': 276,
#   'state': 0},
#  2: {'fw_version': 257,
#   'product_no': 124627,
#   'hw_type': 4734992,
#   'hw_version': 276,
#   'state': 0},
#  3: {'fw_version': 257,
#   'product_no': 124628,
#   'hw_type': 4734992,
#   'hw_version': 276,
#   'state': 0},
#  4: {'fw_version': 257,
#   'product_no': 124629,
#   'hw_type': 4734992,
#   'hw_version': 276,
#   'state': 0}}

# %% [markdown]
# ## Module Info (MOD_ADDR)

# %%
pa.get_module_info(MOD_ADDR)
# Out:
# 2026-03-25 12:27:33,689 - INFO - test_pa - Getting information for module 0
# 2026-03-25 12:27:33,863 - INFO - test_pa - Retrieved information for module 0
# {'product_no': 124625,
#  'fw_version': 257,
#  'hw_type': 4734992,
#  'hw_version': 276,
#  'state': 0,
#  'housekeeping': {'volt_3v3': 3.2981530343007917,
#   'temp_cpu': 25.28,
#   'volt_5v0': 4.997,
#   'volt_12v': 11.955,
#   'volt_3v3i': 3.2981530343007917,
#   'temp_cpui': 28.32,
#   'volt_2v5i': 2.505,
#   'volt_36vn': -35.832933557207966,
#   'volt_20vp': 23.21,
#   'volt_20vn': -23.54381546334053,
#   'volt_15vp': 17.894,
#   'volt_15vn': -17.96693851443192,
#   'volt_1v8p': 1.801,
#   'volt_1v8n': -1.7919964819700969,
#   'volt_vrefp': 1.248,
#   'volt_vrefn': -1.7430239066122972},
#  'current': {'value': -2.8e-13, 'range': 0}}

# %%
pa.get_module_fw_version(MOD_ADDR)
# Out:
# (0, 257)

# %%
pa.get_module_fw_date(MOD_ADDR)
# Out:
# (0, 'Feb  3 2025')

# %%
pa.get_module_product_id(MOD_ADDR)
# Out:
# (0, 'pA-meter module, 1 isolated channel')

# %%
pa.get_module_product_no(MOD_ADDR)
# Out:
# (0, 124625)

# %%
pa.get_module_manuf_date(MOD_ADDR)
# Out:
# (0, 2024, 40)

# %%
pa.get_module_device_type(MOD_ADDR)
# Out:
# (0, 50206)

# %%
pa.get_module_hw_type(MOD_ADDR)
# Out:
# (0, 4734992)

# %%
pa.get_module_hw_version(MOD_ADDR)
# Out:
# (0, 276)

# %%
pa.get_module_uptime(MOD_ADDR)
# Out:
# (-13, 0.0, 0.0)

# %%
pa.get_module_uptime_int(MOD_ADDR)
# Out:
# (0, 6608, 515, 549176, 548)

# %%
pa.get_module_optime(MOD_ADDR)
# Out:
# (0, 333.408, 540422.532)

# %%
pa.get_module_optime_int(MOD_ADDR)
# Out:
# (0, 334, 304, 540423, 428)

# %%
pa.get_module_cpu_data(MOD_ADDR)
# Out:
# (0, 0.763)

# %%
pa.get_module_housekeeping(MOD_ADDR)
# Out:
# (0,
#  3.2981530343007917,
#  25.28,
#  4.997,
#  11.956,
#  3.2981530343007917,
#  28.29,
#  2.505,
#  -35.832933557207966,
#  23.211,
#  -23.544814903653954,
#  17.895,
#  -17.96693851443192,
#  1.801,
#  -1.7919964819700969,
#  1.248,
#  -1.7430239066122972)

# %%
pa.get_module_state(MOD_ADDR)
# Out:
# (0, 0)

# %%
pa.get_module_buffer_state(MOD_ADDR)
# Out:
# (0, True)

# %%
pa.get_module_ready_flags(MOD_ADDR)
# Out:
# (0, 6)

# %%
pa.get_scanned_module_params(MOD_ADDR)
# Out:
# (0, 124625, 124625, 4734992, 4734992)

# %% [markdown]
# ## Module Measurement

# %%
pa.get_module_meas_range(MOD_ADDR)
# Out:
# (-13, 0, False)

# %%
pa.set_module_auto_range(MOD_ADDR, True)
# Out:
# 0

# %%
pa.set_module_meas_range(MOD_ADDR, 0)
# Out:
# 0

# %%
pa.get_module_current(MOD_ADDR)
# Out:
# (-13, 0.0, 0)

# %% [markdown]
# ## Automatic Current

# %%
pa.get_automatic_current()
# Out:
# (0, False)

# %%
pa.set_automatic_current(True)
# Out:
# 0

# %%
pa.get_automatic_current()
# Out:
# (-13, False)

# %%
pa.get_current()

# %%
pa.set_automatic_current(False)

# %% [markdown]
# ## Configuration

# %%
pa.get_current_config()

# %%
pa.get_config_flags(0)

# %%
pa.get_config_name(0)

# %%
pa.get_config_data(0)

# %% [markdown]
# ## Error / Interface State

# %%
pa.get_interface_state()

# %%
pa.get_error_message()

# %%
pa.get_io_state()

# %%
pa.get_io_error_message()

# %%
pa.get_comm_error()

# %% [markdown]
# ## PA Convenience Methods

# %%
pa.get_status()

# %%
pa.hk_monitor()

# %% [markdown]
# ## Housekeeping Thread

# %%
pa.start_housekeeping(interval=5)

# %%
import time
time.sleep(10)  # let housekeeping run ~2 cycles

# %%
pa.stop_housekeeping()

# %% [markdown]
# ## Disable + Disconnect

# %%
pa.set_enable(False)

# %%
pa.disconnect()
# Out:
# 2026-03-25 12:29:32,739 - INFO - test_pa - Disconnecting PA device test_pa
# 2026-03-25 12:29:32,752 - INFO - test_pa - Successfully disconnected PA device test_pa
# True

# %%
print(f"Log file: {log_file}")
# Out:
# Log file: C:\Users\ESIBDlab\PycharmProjects\esibd_bs\debugging\logs\017_Testing_pA_20260325_121801.log
